# %% [markdown]
# <a href="https://www.kaggle.com/code/ganeshmohane/pandas-all-methods?scriptVersionId=255562179" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Pandas: Its derived from panel data means tabular data set, pandas is used for data cleaning, processing and analysis purpose and its very fast

# %%
import pandas as pd

# %% [markdown]
# ## Create DataFrame

# %%
# Create DataFrame

StudentData = {
    'Id': [ 1, 2, 3 ],
    'Name':['Ganesh', 'Manesh', 'Suresh']
}

df = pd.DataFrame(StudentData)
df.head()

# OR

df = pd.DataFrame({
    'id': [1, 2, 3],
    'Name': ['Ganesh', 'Manesh', 'Suresh']
})
df.tail()
# Out:
#    id    Name
# 0   1  Ganesh
# 1   2  Manesh
# 2   3  Suresh

# %% [markdown]
# ## Explore dataset

# %%
df.head()
# Out:
#    id    Name
# 0   1  Ganesh
# 1   2  Manesh
# 2   3  Suresh

# %%
df.tail()
# Out:
#    id    Name
# 0   1  Ganesh
# 1   2  Manesh
# 2   3  Suresh

# %%
df.describe()
# Out:
#         id
# count  3.0
# mean   2.0
# std    1.0
# min    1.0
# 25%    1.5
# 50%    2.0
# 75%    2.5
# max    3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   Name    3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.columns
# Out:
# Index(['id', 'Name'], dtype='object')

# %%
df.Name.describe() # we can use describe for particular cols as well
# Out:
# count          3
# unique         3
# top       Ganesh
# freq           1
# Name: Name, dtype: object

# %% [markdown]
# ## Dealing with null values

# %%
# drop rows with null values

df = df.dropna()

# %%
# count null values for whole df
df = pd.read_csv('/kaggle/input/engineering-student-results-sem-05-2024/cleaned_data.csv')

print('null count for df:',df.isnull().sum())
print('null count for column:',df['Seat No'].isnull().sum())
# Out:
# null count for df: Seat No                                                                0
# Computer\nNetwork - ESE                                                0
# Computer\nNetwork - IA                                                 0
# Computer\nNetwork - TOT                                                0
# Web Computing - ESE                                                    0
# Web Computing - IA                                                     0
# Web Computing - TOT                                                    0
# Artificial Intelligence & Lab - ESE                                    0
# Artificial Intelligence & Lab - IA                                     0
# Artificial Intelligence & Lab - TOT                                    0
# Artificial Intelligence & Lab - PROR                                   0
# Artificial Intelligence & Lab - TW                                     0
# Artificial Intelligence & Lab - TOT.1                                  0
# Data Warehousing & Mining and Lab - ESE                                0
# Data Warehousing & Mining and Lab - IA                                 0
# Data Warehousing & Mining and Lab - TOT                                0
# Data Warehousing & Mining and Lab - PROR                               0
# Data Warehousing & Mining and Lab - TW                                 0
# Data Warehousing & Mining and Lab - TOT.1                              0
# D.L.O.C-I- Statistics\nfor Artificial\nIntelligence and Data - ESE     0
# D.L.O.C-I- Statistics\nfor Artificial\nIntelligence and Data - IA      0
# D.L.O.C-I- Statistics\nfor Artificial\nIntelligence and Data - TOT     0
# Web Computing\nand Network Lab - PROR                                  0
# Web Computing\nand Network Lab - TW                                    0
# Web Computing\nand Network Lab - TOT                                   0
# Professional\nComm. & Ethics-II - PROR                                 0
# Professional\nComm. & Ethics-II - TW                                   0
# Professional\nComm. & Ethics-II - TOT                                  0
# Mini Project-2A - PROR                                                 0
# Mini Project-2A - TW                                                   0
# Mini Project-2A - TOT                                                  0
# Total                                                                  0
# SGPI                                                                  11
# Result                                                                 0
# CGPI                                                                   0
# dtype: int64
# null count for column: 0

# %%
# fillna 

mean = df.SGPI.mean()
df.fillna({'SGPI':mean}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Seat No                                                               0
# Computer\nNetwork - ESE                                               0
# Computer\nNetwork - IA                                                0
# Computer\nNetwork - TOT                                               0
# Web Computing - ESE                                                   0
# Web Computing - IA                                                    0
# Web Computing - TOT                                                   0
# Artificial Intelligence & Lab - ESE                                   0
# Artificial Intelligence & Lab - IA                                    0
# Artificial Intelligence & Lab - TOT                                   0
# Artificial Intelligence & Lab - PROR                                  0
# Artificial Intelligence & Lab - TW                                    0
# Artificial Intelligence & Lab - TOT.1                                 0
# Data Warehousing & Mining and Lab - ESE                               0
# Data Warehousing & Mining and Lab - IA                                0
# Data Warehousing & Mining and Lab - TOT                               0
# Data Warehousing & Mining and Lab - PROR                              0
# Data Warehousing & Mining and Lab - TW                                0
# Data Warehousing & Mining and Lab - TOT.1                             0
# D.L.O.C-I- Statistics\nfor Artificial\nIntelligence and Data - ESE    0
# D.L.O.C-I- Statistics\nfor Artificial\nIntelligence and Data - IA     0
# D.L.O.C-I- Statistics\nfor Artificial\nIntelligence and Data - TOT    0
# Web Computing\nand Network Lab - PROR                                 0
# Web Computing\nand Network Lab - TW                                   0
# Web Computing\nand Network Lab - TOT                                  0
# Professional\nComm. & Ethics-II - PROR                                0
# Professional\nComm. & Ethics-II - TW                                  0
# Professional\nComm. & Ethics-II - TOT                                 0
# Mini Project-2A - PROR                                                0
# Mini Project-2A - TW                                                  0
# Mini Project-2A - TOT                                                 0
# Total                                                                 0
# SGPI                                                                  0
# Result                                                                0
# CGPI                                                                  0
# dtype: int64
