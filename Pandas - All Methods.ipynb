# %% [markdown]
# <a href="https://www.kaggle.com/code/ganeshmohane/pandas-all-methods?scriptVersionId=255819985" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Pandas: Its derived from panel data means tabular data set, pandas is used for data cleaning, processing and analysis purpose and its very fast

# %%
import pandas as pd

# %% [markdown]
# ## Create DataFrame

# %%
# Create DataFrame

StudentData = {
    'Id': [ 1, 2, 3 ],
    'Name':['Ganesh', 'Manesh', 'Suresh']
}

df = pd.DataFrame(StudentData)
df.head()

# OR

df = pd.DataFrame({
    'id': [1, 2, 3],
    'Name': ['Ganesh', 'Manesh', 'Suresh']
})
df.tail()

# %% [markdown]
# ## Explore dataset

# %%
df.head()

# %%
df.tail()

# %%
df.describe()

# %%
df.info()

# %%
df.columns

# %%
df.Name.describe() # we can use describe for particular cols as well

# %% [markdown]
# ## Dealing with null values

# %%
# drop rows with null values

df = df.dropna()

# %%
df = pd.read_csv('/kaggle/input/engineering-student-results-sem-05-2024/cleaned_data.csv')

# %%
# count null values for whole df
print('null count for df:',df.isnull().sum())
print('null count for column:',df['Seat No'].isnull().sum())

# %%
# fillna 

mean = df.SGPI.mean()
df.fillna({'SGPI':mean}, inplace=True)

# %%
df.isnull().sum()

# %% [markdown]
# ### check data types and convert

# %%
df.dtypes
# Out:
# Seat No                                                                object
# Computer\nNetwork - ESE                                                object
# Computer\nNetwork - IA                                                 object
# Computer\nNetwork - TOT                                                 int64
# Web Computing - ESE                                                    object
# Web Computing - IA                                                     object
# Web Computing - TOT                                                    object
# Artificial Intelligence & Lab - ESE                                    object
# Artificial Intelligence & Lab - IA                                     object
# Artificial Intelligence & Lab - TOT                                     int64
# Artificial Intelligence & Lab - PROR                                   object
# Artificial Intelligence & Lab - TW                                     object
# ...

# %%
# CGPI is object but it should be float64

df['CGPI'] = df['CGPI'].astype('float64')
df.CGPI.dtypes
# Out:
# dtype('float64')

# %%
df['CGPI'].head()
# Out:
# 0    7.1
# 1    6.6
# 2    8.5
# 3    7.5
# 4    4.2
# Name: CGPI, dtype: float64
